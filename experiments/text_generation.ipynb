# %% [markdown]
# # LSTM Text Generation
#
# Tutorial from: https://keras.io/examples/generative/lstm_character_level_text_generation/
#
# Generates sentences using an LSTM.
# Given a seed phrase, the model samples from the available characters to generate a sentence of set length.
#
# ## Basic architecture
# Input -> LSTM -> Dense -> Softmax
#
# Input: One-hot encoded sentences
#
# ## Softmax temperature
# The novelty of the generated sequence can be determined using the *Temperature* of the softmax. When the softmax output is considered as a probability distribution, we can tweek this distribution to make samples more or less suprising.
#
# By reweighting the distribution we can determine how novel the next sequence is.
# Low temperature -> More deterministic
# High temperature -> More stochastic

# %%
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import random
import io

# %%
# Load data
path = keras.utils.get_file("nietsche.txt", origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt")
with io.open(path, encoding="utf-8") as f:
    text = f.read().lower()
text = text.replace("\n", " ")
print("Corpus length: {}".format(len(text)))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# 614400/600901 [==============================] - 0s 0us/step
# Corpus length: 600893

# %%
max_length = 60
step = 3 # New sequence is sampled after three characters
sentences = []
next_chars = [] # Holds the targets


for i in range(0, len(text) - max_length, step):
    sentences.append(text[i: i + max_length])
    next_chars.append(text[i + max_length])

print("Number of sequences: {}".format(len(sentences)))

chars = sorted(list(set(text)))
print("Total number of characters in corpus: {}".format(len(chars)))

char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# Number of sequences: 200278
# Total number of characters in corpus: 56

# %%
sentences[5]
# Out:
# 'sing that truth is a woman--what then? is there not ground f'

# %%
# Vectorization

# One-hot encode characters into a 3D array.
# Dim 1: Sentence number i
# Dim 2: Character t from the i-th sentence
# Dim 3: One-hot 1D array which encodes the t-th character of the i-th sentence. Length: len(chars)
x = np.zeros((len(sentences), max_length, len(chars)), dtype=bool)
y = np.zeros((len(sentences), len(chars)),dtype=bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %%
# Build model
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(max_length, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
# Sample from the text
random.seed(1843)

def sample(preds, temperature=1.0):
  preds = np.asarray(preds).astype("float64")
  preds = np.log(preds) / temperature
  exp_preds = np.exp(preds)
  preds = exp_preds / np.sum(exp_preds) # So that they sum up to 1
  probas = np.random.multinomial(1, preds, 1) # Draw 1 sample from the preds
  return np.argmax(probas)

# %%
# Train the model
epochs = 60
batch_size = 128

for epoch in range(epochs):
  model.fit(x,y, batch_size=batch_size, epochs=1)
  print()
  print("Generating text after epoch: %d" %epoch)
  start_index = random.randint(0, len(text) - max_length - 1)
  
  for diversity in [0.2, 0.5, 1.0, 1.2]:
    print("...Diversity:", diversity)

    generated = ""
    sentence = text[start_index : start_index + max_length]  
    print("...Generating with seed: " + sentence)

    for i in range(400):
      x_pred = np.zeros((1, max_length, len(chars)))
      for t, char in enumerate(sentence):
        x_pred[0, t, char_indices[char]] = 1.0
      preds = model.predict(x_pred, verbose=0)[0]
      next_index = sample(preds, diversity)
      next_char = indices_char[next_index]
      sentence = sentence[1:] + next_char
      generated += next_char

    print("...Generated: ", generated)
    print()
# Out:
# 1565/1565 [==============================] - 25s 16ms/step - loss: 1.4006
#
# Generating text after epoch: 0
# ...Diversity: 0.2
# ...Generating with seed: bly it even flattered the heart and taste of kant: let us ca
# ...Generated:  se of the best and the sense of the seems to the seems to the servical still the seems of the seems to the sense of the seems to the seems to be the seems to be the seems to the seems to the seems of the seems to the consequence of the seems to be the strong and and the seems of the seems to the such a such a such a comparestorow and the seems to the seems to be the sense of the seems to his still
#
# ...Diversity: 0.5
# ...Generating with seed: bly it even flattered the heart and taste of kant: let us ca
# ...Generated:  n be the such a rackure us an accurage is only his present of the case of the example of the sense of the way and in its ventures and considered also be have its restruct in an accession of comparestian that any highest standard and the extred to the seems of the profound, and being of extent of the conscience of the beauty in a profound and forming which the actions and which a command--and in th
#
# ...Diversity: 1.0
# ...Generating with seed: bly it even flattered the heart and taste of kant: let us ca
# ...Generated:  n inserices calless make fourres takingly pleasure's have indeed, so it no "invellest actions, such an asort and steady and another discept of their position of some regreat, they sees may be rend it thinkinnatians firals or the too-had commantime, as thirstiness" is the very propectation of the imeffied.   t  =taste of such a means and wosterful distinguistful and instincts of the believe but in
#
# ...Diversity: 1.2
# ...Generating with seed: bly it even flattered the heart and taste of kant: let us ca
# ...Generated:  nibw! lassebs impleetyy;--this.--vertlefnimous and demanplest of but prytomenet of virtue.  o ungase ourghens, oljed the musthor of live. it sainter, their surquided, in order statoses, who the interestian causers of natureing of missatoments, superhind that is which do. the winable this is attain.  regil bain; he jeaul. feuslous false, was nof blim take use greetogiin europe christianisuouim-was
#
# 1565/1565 [==============================] - 29s 18ms/step - loss: 1.3784
#
# Generating text after epoch: 1
# ...Diversity: 0.2
# ...Generating with seed:  greek religion.   112  =at the contemplation of certain anc
# ...Generated:  ies the individuals of the serve the spirit, and so that the spirit of the superitic of the sense of the senses and the individuals of the the superitic of the strength in the act and senses of the spirit of the greatest and more the superitic of the greatest and so make the sense of the seriously the proves, and it is all the subtle the superitician and man is an intergreative the the proves and
#
# ...Diversity: 0.5
# ...Generating with seed:  greek religion.   112  =at the contemplation of certain anc
# ...Generated:  ies to good and senses and considerations of the propertion to the result.   1   ingariaticism is an almost in the experience and significance, as the one from the transpages the men prevail of the "faculty of which he is so that the gradutefous and free spirits of he from the trated and so the greatest and conscious and the distrust whatever the world in the prison, and away, it was all one of th
#
# ...Diversity: 1.0
# ...Generating with seed:  greek religion.   112  =at the contemplation of certain anc
# ...Generated:  oncrrain how teither. whether more which which, old its philosophy world power together of born, di  quence of neighbous to min the exist the threstfbfrom fine, and mis its experience is any must questions of any ped with power, doitual of those thought, through af the depecially aunt. whether and angary: tothe . when the mediocjus prensery any the reblenger of the almeate makes for gois. or said
#
# ...Diversity: 1.2
# ...Generating with seed:  greek religion.   112  =at the contemplation of certain anc
# ...Generated:  le't, whist hourarfrow. it certainly. whtoked--ias strength has sylevernes and dfated upon aokpposint, to romanned has grad another-anape.--whoave popression"; wanaxce, when a rome thereby in must exocisy were prefersning of seecy, agtion, immediegates--stiul," spire royy, so he liberable, the o.f's spiritly that croe to hesery of condiancred authoring they. imperiticsily of exdeassmitism in which
#
# 1565/1565 [==============================] - 28s 18ms/step - loss: 1.3617
#
# Generating text after epoch: 2
# ...Diversity: 0.2
# ...Generating with seed: is lighter, purer, happier soul, quickly acquired admiration
# ...Generated:   of the commanded that the spirit of the spirit of the consequence of the sense and all the spirit of the such a charms of the same in the such a man is the same in the spirit of the world and an are that which is the spirit of the such a man is the most that the same a change and such a more consequence of the spirit of the conseried that the superior of the instinct of the such a man is the same
#
# ...Diversity: 0.5
# ...Generating with seed: is lighter, purer, happier soul, quickly acquired admiration
# ...Generated:   of the framuther and the spirit that the which that the spirit which all the experience and the experience is all therefore, as the creased on the most than are only the process as a have that it is not all the away, and and self-contempt the religion, as a statesnary and good and all the intellect of the heart this contrary and christian the conserted in the assumed his own suspect that the stro
#
# ...Diversity: 1.0
# ...Generating with seed: is lighter, purer, happier soul, quickly acquired admiration
# ...Generated:   of mesthje-coold affigit of may si proquesition, by ahmonders of which sees of anyory, and sacrifications in the effect dreadfully, the way great fell cound for expelse, the reason consicking morulal self-1distance. petually soultheredies somereital estanes a gorse that nee-comitions. the opparint recerning with oneit is mererion of the super: that that revolution more higher, sinal, that the gru
#
# ...Diversity: 1.2
# ...Generating with seed: is lighter, purer, happier soul, quickly acquired admiration
# ...Generated:  , when all pheno, fellishe phonoureramentardicians sufficiat all honor, windhest a rorgbyliness verse--and spirit which esternes this, voily that the sunes, circlust1lies therrow womanprific taf awiars" within honorence, someer, by thus cold lost, admint good which we bring" may some: "much as an actally, to clvist nature, only he when the naturectual rilf, as a rumbered if seck than on itsesing,
#
# 1565/1565 [==============================] - 29s 19ms/step - loss: 1.3479
#
# Generating text after epoch: 3
# ...Diversity: 0.2
# ...Generating with seed: wards those who are "the rules." after all, they have more t
# ...Generated:  he developed the same the self-contradity of the same the the developed the self-contradity the world and all the same the last and the same an accordance the subjuction of the same a man will be an accordance of the self-contradity and the self-contradity and the conception of the same the self-contradity that the sense of the sense of the self-religious and say that the self-delications of the s
#
# ...Diversity: 0.5
# ...Generating with seed: wards those who are "the rules." after all, they have more t
# ...Generated:  he cause society and self the consequently be with the need of the same a the and the explanation in the entimetfatic and souther and all the contradities of the intellectually be nee age and property and of the servant can again of the dunger, and an according the man accordant and the action and an actions, in the sense in a the words of the inversrous one rosing in the state and contraditation
#
# ...Diversity: 1.0
# ...Generating with seed: wards those who are "the rules." after all, they have more t
# ...Generated:  riakly esmonate metaphysics name and his own would not be time an equally entere of fortical actions are whetever, and into that which too. mank-angage all consequenes it might those master an-inss from the crainness, as the enor" which seneitatr and whozer probles of evilse by his priomintgen inferious temptenculari, a valuation of badare? are souch," the relation" and precoune delisable anaic re
#
# ...Diversity: 1.2
# ...Generating with seed: wards those who are "the rules." after all, they have more t
# ...Generated:  eruntarife. the beganist is had teval; for at the , accordinrem of scholarsed and flow, palp, as recelp-spare to greater, choold: seldomen seepsible and peratisg to toin" if scholark to the would be hotuen itself a yeal feel one"--his fortute falsely the ages is do, let varupel of those society.=--qulak. the genous thious--in each. brfquance as deadsrifes, both stall gehtarit? and how indeed, are
#
# 1565/1565 [==============================] - 30s 19ms/step - loss: 1.3395
#
# Generating text after epoch: 4
# ...Diversity: 0.2
# ...Generating with seed: assuming seriousness, and without much curiosity or discomfo
# ...Generated:  rd the probably and the strength of the sense of the self the progress of the fact the desires the probably the probably the sense of the sense of the progress of the world of the promises that it is the sense and the progress. the probably all the progress of the sense and allowed the desires the development of the promises of the sense of the most probably in the self the promised that is the se
#
# ...Diversity: 0.5
# ...Generating with seed: assuming seriousness, and without much curiosity or discomfo
# ...Generated:  rscation and strangers of the comparess of all the comparess of the ethice of the sense in the estement of the probably the prioroses to the called the devils, and as one is not be something doubt it is one's really all the destruction is the more probably the dispoming of the superficial to the compare of superficial possess of the fands of it wishes to the sense the former will also the problem
#
# ...Diversity: 1.0
# ...Generating with seed: assuming seriousness, and without much curiosity or discomfo
# ...Generated:  rts, in poscect,edy--well coptenet to deciness and polise wimponing that west generally to longs a power-es.  -ideflict the longer man dours, everyreine action of the outgius, and hope. life ourselves himself withdromented placed worldency halmers ulturious and on things, untimes, echourness--as the highest perceived   peop-formacce of nolle. thinks, while intercourse of there poles that we may no
#
# ...Diversity: 1.2
# ...Generating with seed: assuming seriousness, and without much curiosity or discomfo
# ...Generated:  rscandad. throtgeness: their t : knew to so account their dumasism, swalp, ho"rngminat uik. educence, ordanument, which..--savicion and which others brenes, lending that multinging, youthboner, happecy, as mutus in thoutrof". if the errordans and myspeor and ad; and the lrastfule idea").--to thorg artsfaract, the intellecting wondures? ousged or life really and doughtion is that withhy, abbecti wo
#
# 1565/1565 [==============================] - 28s 18ms/step - loss: 1.3278
#
# Generating text after epoch: 5
# ...Diversity: 0.2
# ...Generating with seed: ; only that here and there perhaps some sailor's home-sickne
# ...Generated:  ss of the strength of the stringt of the spirits of the future that the same the strange of the state of the strong of the stand the fact of the common the strength of the stand the same the stringt of the same the stand the consequently of the state of the constant the compares of the strong and stand the stringt of the constance of the standard and state and desires and stand of the state of the
#
# ...Diversity: 0.5
# ...Generating with seed: ; only that here and there perhaps some sailor's home-sickne
# ...Generated:  ss of the for him states and and delights of the acts of the constating that the constitute of endure experiences to the strangenic of the unifines there in our "strong the belief in the ward of the stringt the strengthy of the feeling and superioch hustory and attempt to his lived and such a long of religious the same father the human who has that of religious man is a more perhaps consignt of th
#
# ...Diversity: 1.0
# ...Generating with seed: ; only that here and there perhaps some sailor's home-sickne
# ...Generated:  ss veryous been terrible all acts bound; hivouscys--yingren, and perhaps reasonact pressy of metaphysic sympathy alsocwable dayll, and his defecting of all anyound the powerlan acts cleavy, and christian independence of aapsly of sufferent a complinges our religiousness of one with les and still times un elenat being all an start relaticides. somethings. that which he har testence a akare up the r
#
# ...Diversity: 1.2
# ...Generating with seed: ; only that here and there perhaps some sailor's home-sickne
# ...Generated:  ss" of this circumscones, he has once enthuch? angthre? what is pats educattels, or german rekince, eyestatire by our feel hush, who haw find in something to parayy spirit of staper for then grours, it if butwho see mordoriesus manketena-"s-ti complete deceiver a naturefulness and is alh; such hole springivid laulonene-final flot up.  1oignt out.  ore too human same rumatic supposite in the fratht
#
# 1565/1565 [==============================] - 28s 18ms/step - loss: 1.3187
#
# Generating text after epoch: 6
# ...Diversity: 0.2
# ...Generating with seed: s than to be precisely this causa sui, and, with more than m
# ...Generated:  any "the sense of the constrabind the moral the same profound the same the same the world to be a profound and the actions of the same as the sense of the constraint of the constraint of the constrable precisely be as the sense of the constrable and such a power the same as the soul and and the sense of the same as the same as the fact the present of the present of the contradict of the sense of t
#
# ...Diversity: 0.5
# ...Generating with seed: s than to be precisely this causa sui, and, with more than m
# ...Generated:  an so long the estect the end which the spirit their opposite of the truth of the contempt of the the victor in the spirit of the same a power the time, in the further about the present and soul is in the most desire the fact of society and the new truth and conscience, the more invention is to seems the world, yet be and knowledge of the constrables the same to in the contrary of the same who are
#
# ...Diversity: 1.0
# ...Generating with seed: s than to be precisely this causa sui, and, with more than m
# ...Generated:  acks and sout"psting europeal towards means least accooning justs--namely, hered those and do with we godden" are ward, of under the constrasion now godd, vomectar and the opinion, from the contemptible secon history oveguring the imhilenges"!  , iard name of the hatical alat. certain wrongle anting brity of frailder of supposition for the you giving. he is a unpresso"--in viely of get hereful but
#
# ...Diversity: 1.2
# ...Generating with seed: s than to be precisely this causa sui, and, with more than m
# ...Generated:  oralse would carries of god; forget revealed--this sapabious vay bydiem itiust on the dangeriousned of this "sympatiful navourious inmored, o; he is wictory.ibitharia sendagantly cheatter have lose one ofo transcount unbelling like liniffer of jesus at present often tcapided synthesion of jake frleardmented, old "bard a oldippe about our a trued net a truepsnesswords there nee-dis thongaung. moupe
#
# 1565/1565 [==============================] - 29s 19ms/step - loss: 1.3095
#
# Generating text after epoch: 7
# ...Diversity: 0.2
# ...Generating with seed:  pitch; in the same manner as in the last century, when all
# ...Generated:  the sense of the subed that the struggle, and the senses of the struggle, as the problem and the perhaps a conception of the possibility of the man is all the philosophers of the greater in the precisely as the spirit and the strength and desires that the strength of the here and senses of the senses of the senses of the subed to the senses of the promise of the strength of the sense of the same t
#
# ...Diversity: 0.5
# ...Generating with seed:  pitch; in the same manner as in the last century, when all
# ...Generated:  the bad a sense of the philosophers and its so may be present that the most acts who are the senses of the soul that the constrained in the spirit is attent of the dring to precisely to have been the whole such as the higher method, lives to the spirit and so in the conception of the allow to restry a still which he is attained is the precisely in no long the problem in every very the most and lit
#
# ...Diversity: 1.0
# ...Generating with seed:  pitch; in the same manner as in the last century, when all
# ...Generated:  thoughtent been that he anties to gloworks for the great of haty undistuand in iccares blemssfore and the conceptionable; all massesty repacted scremiture, and whereble--he dust-divilations, that rendered with be so that one soul is ever to god-to the workon thereed, is got"-falsehook (and so discoures and amountly, who latter in over that this old, is alre'dibut the regarded a gases of eye to the
#
# ...Diversity: 1.2
# ...Generating with seed:  pitch; in the same manner as in the last century, when all
# ...Generated:  antion ahoe to somethingues but "false, is to up" is no any methadiance, he "europeen in cebtuiour: a hencethe-plose decruede be makeon, spirit," ren licts--in their verythlisrd, the igfoug in the most contames rende":--conssiation weres! excacismant belithey!ly(e, fronthyk"--wh e"f; and s owibt under through which it vearait of emberacaitly imsense, to its best had oh.=--alwayser, new traigres ro
#
# 1565/1565 [==============================] - 28s 18ms/step - loss: 1.3044
#
# Generating text after epoch: 8
# ...Diversity: 0.2
# ...Generating with seed: alse, that is to say, superficial interpretation of every wo
# ...Generated:  rd and the stronger and sufficient to the strength and and and decided and same to the strength of the standard of the strength and sufficient and the delight of the strength of the spirit and man in the same to the fact to the strength of the contemption of the strength of the strength of the sense of the still really the standard of the strength in the strength and such a still morality and suff
#
# ...Diversity: 0.5
# ...Generating with seed: alse, that is to say, superficial interpretation of every wo
# ...Generated:  rst, and believe it for the standard to the contonsition of the world and sufficient to the will and conscience of the standing in order to mankind be reason with every good opinion and good and such a delight of the fact to which he will to this of conscience of the spirit and morality, or purity of the most suprems of the type to be learn to be more to be contemptine and courage of the sense of
#
# ...Diversity: 1.0
# ...Generating with seed: alse, that is to say, superficial interpretation of every wo
# ...Generated:  rd and which had not award and labour reavored grow things, it persetter so emagies of thicking--and there is now too the love the very farsous unforgix insteming and fir men instinct as they make the spirit of the colorical men eagerian, that do sundered freedom. but even with their hardness to dangers. however, and but now intentional future for inatinaler- means, he would probrss spreat", and i
#
# ...Diversity: 1.2
# ...Generating with seed: alse, that is to say, superficial interpretation of every wo
# ...Generated:  rdable spirit thought ocyond noor result that is p its ancle impurhened e"biuder? enemse--that i sfeiw. over is formed sharp, that may be thereto sngartful, do like that dod those vi ow?        13. like its fious neegor--he has we false,     . lit way in his speans sychates and provest lined.   8  o iverrayment: line to the point of what this farsion."  hi colol, demotement of it, become oped too
#
# 1565/1565 [==============================] - 28s 18ms/step - loss: 1.2991
#
# Generating text after epoch: 9
# ...Diversity: 0.2
# ...Generating with seed:  to which we give a good name in order to do whatever we ple
# ...Generated:  asure and strength of the sense of the sense of the sense of the sense of the sense of the present of the seems and the man and the sense of the sense of the present of the man is a consequently the sure the present of the consideration of the everything the sense of the sense of the sense of the strength of the sense of the sense of the sense of the serves of the sense of the sense of the sense o
#
# ...Diversity: 0.5
# ...Generating with seed:  to which we give a good name in order to do whatever we ple
# ...Generated:  asure of the event of consideration of the sense of greatness and a sources--they were of the regard to the even in the for the sublime of the same time this secret to the power in value of the present will which the developed the same man is the german disterptrant and self precisely a the present prover man and in the agreek the according the relations of the father and desparation of the soul,
#
# ...Diversity: 1.0
# ...Generating with seed:  to which we give a good name in order to do whatever we ple
# ...Generated:  asions for complied for class struggleent, noy one, we have presominate the unif the bord. yor in order travely philosophy singed of much bedieasi, a beautifie--less political ghing he conduct confusive, organism, of for speak that of o.with for all mistesthesce the ething example ye invertion and the same ambedes badness, the bams which "its sours, indunef a necessary reduege seemeny with the occ
#
# ...Diversity: 1.2
# ...Generating with seed:  to which we give a good name in order to do whatever we ple
# ...Generated:  ate oursely more, as recrogom linty orignated evality shall alre man is stipulisary may stoulg not; beyondent fory from europe vio,". , wand self-one may be even from oh! onter fell. feund--it wooks. sandiciane to men, a is, coed dy feels the draamakes, fair mince, the, right" lath serpiors. "deys, let buchtboricissments? short, for life hagarced--ceast of life," siptes and the, perhaps adqute" th
#
# 1565/1565 [==============================] - 28s 18ms/step - loss: 1.2915
#
# Generating text after epoch: 10
# ...Diversity: 0.2
# ...Generating with seed:  a radical blending of classes, and consequently of races, i
# ...Generated:  n the same to a soul is a consideration of the senses and the german process of the same to the sense of the senses of the most desire to precisely which the and soul and self the same to the same to an accompan and such a senses of the proposint of the senses of the same to the same to say that is in the same to consideration of the same to make the same to commons the commanding to the senses of
#
# ...Diversity: 0.5
# ...Generating with seed:  a radical blending of classes, and consequently of races, i
# ...Generated:  n order to a post whose conscience and consideration of the self of the propachity of the truth and sanace perciived the sort of the self-religious as a state of many involuntarily power. the paroby man is the attect in the first originates to make the will and pain and nothing and delights of the personal and are senses with the seldops of the spirit of the most conscience is a master of that whi
#
# ...Diversity: 1.0
# ...Generating with seed:  a radical blending of classes, and consequently of races, i
# ...Generated:  nto monically , for all upon a  sure losingd. this last feithters har birre sadeing of the servative might inles him to loor absinated adale--they has will condemnibly, has pencalism freelisess he us pited that the whole the attrodvations, whether the certain the comparatis take out of the soul with this femal conststiy in him the to, prederreble!" let us condee case; silentesion and the id, as ju
#
# ...Diversity: 1.2
# ...Generating with seed:  a radical blending of classes, and consequently of races, i
# ...Generated:  ts "post alsouthy writest wimpers owakind in the value envxo"--they alles maniles worldly light of emmedy not, is that the allatainturnations and here" impectiand and remances in a cercomouight, the psecesla, had groblen regalled faculty, a potently, which, as it is fellow comaming. may as imposceble", that all over, payting-gwaring destiny. it is one could be took--this has percialite? even igner
#
# 1565/1565 [==============================] - 26s 17ms/step - loss: 1.2849
#
# Generating text after epoch: 11
# ...Diversity: 0.2
# ...Generating with seed: : "thou art more! thou art higher! thou hast a different ori
# ...Generated:  ginates to the fundamental philosophers and the sense of the most subtle the spirit and profound and the most personal and sublimed to be the subtle the subtle the spirit and consciences, the subtle the sense of the sublimeties and the matter of the subtle to the most antight and the the best the sense of the conscience and the matter and the sense of the sublimeties and the subtle the subtle that
#
# ...Diversity: 0.5
# ...Generating with seed: : "thou art more! thou art higher! thou hast a different ori
# ...Generated:  gination of the thought and internal feelings of his soul very substing enter into the termity of the sense of the superiority has the power and the world and place in the compansistians and complicity and the most philosophers as a schopenhauer's only in conscience is belong man the consciences and the best internal attention, and partial still internal still falseher become to the spirit interre
#
# ...Diversity: 1.0
# ...Generating with seed: : "thou art more! thou art higher! thou hast a different ori
# ...Generated:  ganion, that intermine to part! man they allisemsticias folly formed that in his lawlanger: even under edest are , is had as interlie the bascon of abstines, (the sacher! the doubly snictions i islity. skeptick, as we volutien a tay use--under truth--urthouries. the  bitaking equal extent. the powerless gedebllor. to nance of the liver, wo mmy wears milty them cass of penonly it may  taste than ag
#
# ...Diversity: 1.2
# ...Generating with seed: : "thou art more! thou art higher! thou hast a different ori
# ...Generated:  ginhed who sure that ham question : outhor of degen, dute writtesimes formual"--almo" di whupt, alluces brcliek, preference, with it (lived, in hestranring and waiture with tiltuded and education. what socred at to rismary reasonoue tyfeix, i eccourse saint all an eles using," with his feman turting, indeliitts kelshed, they, as carry, "dwelhicazzationiarity, icqurious praise a delicate of this ma
#
# 1565/1565 [==============================] - 27s 17ms/step - loss: 1.2795
#
# Generating text after epoch: 12
# ...Diversity: 0.2
# ...Generating with seed: e physiological sciences and to the history of the evolution
# ...Generated:   of the sense of the sense of the sense of the same and contempt the submlises and the sensual and the sense to the sense of the contrary, the sensual and the same a the sensuint and conscience and the sensual and in the sense and an and antical problem of the sensuines of the contrary, and an actually seems and the truth and the art and delicate man has the sensution the sensuines and such an act
#
# ...Diversity: 0.5
# ...Generating with seed: e physiological sciences and to the history of the evolution
# ...Generated:   and men that a prides itself to the familast contempt of the spirit of evils of such a things and deprivable and the marrite that the self-such an the sensually believes the contemptanity for perhaps have are wholy side he who can be reason the same to the matter in the sense for the lower parten about all the charable proved to the explanation of the mastery and what is not the self-possess to m
#
# ...Diversity: 1.0
# ...Generating with seed: e physiological sciences and to the history of the evolution
# ...Generated:  on". foun his thoous.=--and be sciency through facts of 'morbm. the cappwarity in absolutians death itself corts reglacred, with order to many rare in for the comite past englishmeng in a voice, thereby will be some values--he will victory. the blood prey i profound even the saug", and one to the case in the pretertion and his ways had been, and precisely to degraded, the facts which stope which w
#
# ...Diversity: 1.2
# ...Generating with seed: e physiological sciences and to the history of the evolution
# ...Generated:   of operatagel personal-needed tost dosingd. the dowing fan but in the war, by the most discobedfug, that the smilt is him even as would be sexual in faish called german peaken to taking bothonek--the germanly and one emisity rateless" wo law, what men as tetathys itally moralist mang: ffloued the by wlikenic.  and suprre if we dearun, who al" tee diet, beforest at materians up attempt ups speakd
#
# 1565/1565 [==============================] - 26s 17ms/step - loss: 1.2765
#
# Generating text after epoch: 13
# ...Diversity: 0.2
# ...Generating with seed: task and supremacy of philosophy after all, how could it be
# ...Generated:  still are all the conditions of the proper of the spirit and suble a profound, and the all the self-consequently and states of the fact, and the sublightes of the sense of the sublighter and more and soul of the strength of the conditions of the strength of the self-consideration of the soul of the condition of the strength and states and stronger the strength of the strength of the self-conduct o
#
# ...Diversity: 0.5
# ...Generating with seed: task and supremacy of philosophy after all, how could it be
# ...Generated:  helpanic and decidence of the sense of satisfacred and only a power in the case of the problem of the spendation and desire to his self-responsibility of the intellectually been still perhaps a have been order to the sublightes of perspective profound.
#
# ...Diversity: 1.0
# ...Generating with seed: task and supremacy of philosophy after all, how could it be
# ...Generated:  free will and done, we actually at all with licuation of the boditage and word, are nevertheled lorm to the causation,--e(quantly latter--who has communicial as doubt" of opposing incauling. but inasmaditaricate and dinding around that mecolly incloiver with it is i said, even concate precisely to a antivestile; the tendenes of nu"; leaves another insignely with the itself from the morality in the
#
# ...Diversity: 1.2
# ...Generating with seed: task and supremacy of philosophy after all, how could it be
# ...Generated:  flet to at he subv"quently intescence, after.  1ied precisely, romawismpreans, with truth more as .ckement, does a made beletgey, that where partlessfully being, how profichm. what still accuden by (anim, the t false, it wer solonate age ages. pnetial cannot jece of sagnion aretive action at the moutts, that witmers of life error, there is and musicipss and selly phantbartion.  123--as of decairin
#
# 1565/1565 [==============================] - 30s 19ms/step - loss: 1.2712
#
# Generating text after epoch: 14
# ...Diversity: 0.2
# ...Generating with seed: f millenniums of christianity (for christianity is platonism
# ...Generated:   and self superstition of the seriousness and self super-abouns of the seriousness and allowed the spirit of the self such a genuise the senses of the serious spirit of the self something that the ever persons that it is a more always and such a man who has the present and supersting the spirit and self sublimes that which the spiritual and sole that the precisely before the self something that th
#
# ...Diversity: 0.5
# ...Generating with seed: f millenniums of christianity (for christianity is platonism
# ...Generated:   and superssion of love and absolute and almost the commander, and self-sinding the god, and perhaps about the fance and sometimes opinion of consold and belief in the shame and the fact of one predication of the best of the spiritual strong the dispasirist and the break the commanders, we seem it and self soleme that the longing of the single the greatest and statist in the most disposing the and
#
# ...Diversity: 1.0
# ...Generating with seed: f millenniums of christianity (for christianity is platonism
# ...Generated:  . europe over so much the error. this haws rature far satisfaction and sabwcbeous compares our whodoble fand to reusacy men for the wild fauster, have were to right--this serve ustle: that iscribed only so much which in were was that when we cestine invally accoverary and good forced that the frequermined and, speaking itself by the hoint: it will talkmen falss is not once that the virtues of simp
#
# ...Diversity: 1.2
# ...Generating with seed: f millenniums of christianity (for christianity is platonism
# ...Generated:   thus. one has sublimed, lime. certain "faith world" inexart to hapm be any the lond buarceogr, they found these invadigibleng--na, over amake" formy and imfricidian of hispous bith twaning aquantly pedjust shar more pretisodness.  note even cessic an outchints, to first secceofiment him is wish to helpent reflect press--persith communican natural ond, finer greatest--bigid admiluate cling ent-fec
#
# 1565/1565 [==============================] - 29s 19ms/step - loss: 1.2670
#
# Generating text after epoch: 15
# ...Diversity: 0.2
# ...Generating with seed: be expected, the appearance has translated itself into the s
# ...Generated:  ame to a probably a man were a man we have to be a man we consequence and man with the spirit of the most desires of the super-origent of the same to speak of the subtle the sense that the sense in the spirit and probably the same to the same to the same to the suble an instance, the contradict and sense of the german man is a man were the sublimes of the subtle the subject the subtle in the sense
#
# ...Diversity: 0.5
# ...Generating with seed: be expected, the appearance has translated itself into the s
# ...Generated:  pirit are the symptoms of the heart and the question they are the man and one of the relations of the possess in the works in the spirit and provent in the spirit of suble"--which the assumed and shate of the contradict of sight the promption and more artists had itself with the present conscience of the appearance of the end an about the discording, and in the secondly the most made from the sort
#
# ...Diversity: 1.0
# ...Generating with seed: be expected, the appearance has translated itself into the s
# ...Generated:  pirit connemed its saterished to been schopenhauedere cleak, as dosce--it were bring reflect a decistice friendly feel now world a problem regards in an inzers with which be unfor even ye precisely be conceplion": it isopwantitasion--and subsefous a higher than one had to our bedugsely the ignorable bain think, there of metaphysical hould such his composent moral ufundness of this possekesnister o
#
# ...Diversity: 1.2
# ...Generating with seed: be expected, the appearance has translated itself into the s
# ...Generated:  tence onem breids. lone only tach of europe, indeed still property no order to no diken"), after thabither. in understand grommed ill the sece of will nebqvoment by we noist; his ways? ppilositu thtoute by effleem of truthed fron a changes of ever quiskum is all gery ood, greatigal cimish satity we fe"; for his awness artafers interestjve-esideration, with which i life much, wantor-hrem.stst? fest
#
# 1565/1565 [==============================] - 31s 20ms/step - loss: 1.2629
#
# Generating text after epoch: 16
# ...Diversity: 0.2
# ...Generating with seed: himself the beings in whom the opposite of this exalted, pro
# ...Generated:  tection, and in the conscience, and the deeds of the sense of the same time and all the state of the sense of the sense of the subtle of the constant and deceived the stringt and self-control what is a state, and a state of the same a masters, and the false and the delicate and deceived in the strength of the sense of the state of the state of the state of the state of the state of the most discor
#
# ...Diversity: 0.5
# ...Generating with seed: himself the beings in whom the opposite of this exalted, pro
# ...Generated:  blem and promises the fact that to be standard and such as a something is the profound and the moral worth in every one in the contact of the contemptible the old distinction of the fact that to be have the finest pointed from the nature of a most faith and the sensation the self-conceals and different do not find and the present and condition of the contrary the precisely of all the state of the
#
# ...Diversity: 1.0
# ...Generating with seed: himself the beings in whom the opposite of this exalted, pro
# ...Generated:  ced at us, it precisely satifies of the connects. if so passion with their present, there as immetake the wages thy con, and not believes it not became life to how perhaps healthing and thereon, and chain.       latter to havons, thinkers. there is no look the silaze if one sourse in the ogibation, an evolutions to modeen of evental, the belisting to stranges. as metaphysicas, here by the ecurious
#
# ...Diversity: 1.2
# ...Generating with seed: himself the beings in whom the opposite of this exalted, pro
# ...Generated:  tected by them, anlt thune christian "they sudds offless, which of which sain heresiantranmeme will falsis esphjoccfoulrs ofor(monist upon the ascetime as in now languadd.=--ue darth of the mans, but a disparacy, of gateners, dromp, but philosophilious with his pedsamenthosms, idecoud, at anything curiosity of his concealations the excel, faorical, lagits to the condeed difference, arips"; implite
#
# 1565/1565 [==============================] - 30s 19ms/step - loss: 1.2596
#
# Generating text after epoch: 17
# ...Diversity: 0.2
# ...Generating with seed: r this and act like eager riders who enjoy horseback exercis
# ...Generated:  ing the sense of the most present and the proves to the present distinction of the spirit of the most presumption of the ascetic and the sense of the presumption of the most sense of the present and the greatest man what is the moral the most contempt the contrary and suffering to the contempt the suffering to the present of the sense of the most present and senses of the souls of the most present
#
# ...Diversity: 0.5
# ...Generating with seed: r this and act like eager riders who enjoy horseback exercis
# ...Generated:  ise with it is charms of whom the hast superian powerful of a sort of man and bad sympathy and who say that which may be so that one will be souls of capacted in the tere it who has a higher and at the propert of the senses who has comed to be sense which would be his as the philosophers--of the free spirits and therefore the even the free spirits in the horred to the contempt itself to plato fear
#
# ...Diversity: 1.0
# ...Generating with seed: r this and act like eager riders who enjoy horseback exercis
# ...Generated:  ing itself has herming in freedom forms vortagefully more are deamness frogs of towakis is ro. no cloous worldly bad and formles, and his others, however, does to thre experience. at once trud, one and is methoce almost results of ideas. too here arrive one recognized men in france to our especiamed, and himself where: at outsit one has weatist the fear-prominess intellectudm form of amknow, when
#
# ...Diversity: 1.2
# ...Generating with seed: r this and act like eager riders who enjoy horseback exercis
# ...Generated:  ised sought are ourselves they andful kindly that promiled man him. untoundp? and alshastered--for power. doubtful men-wardly or experiration--for prehont, or may everetace dormances--if one have tong oppociousness. this tentives errfleding by one volected it. the by having merely onerul, the time that great reward, menwaring to the maintter, world dufue or music revede, frem dony round who plato
#
# 1565/1565 [==============================] - 31s 20ms/step - loss: 1.2580
#
# Generating text after epoch: 18
# ...Diversity: 0.2
# ...Generating with seed: lf to one's own tests that one is destined for independence
# ...Generated:  of the sense of the sense of the more profound and the sense of the sense of the sense of the most profound and sangfute. the sense of the contrary and same the profound to the sense of the sense of the sense of the sense of the sense of the sense of the man is all the most deceived the spirit of the sense of the sense the sense of the strength of the sense of the sense of the sense of the german
#
# ...Diversity: 0.5
# ...Generating with seed: lf to one's own tests that one is destined for independence
# ...Generated:  of the tender scholarling to the most conception: it is the something which the passions of things and healt, and also and subject of the souther, the purpose to the term of the heart for himself as the man is in the man as in the spirits of cause there.  1
#
# ...Diversity: 1.0
# ...Generating with seed: lf to one's own tests that one is destined for independence
# ...Generated:  of the will he wanterous atway life thes are any one now. then theken the importimove others. the good by provisent without a smiller and ternibles of the spirit in their facts at the veration that the value of the rule of any man is the smile manner recognize them. feels all if  ratice without opinion of the visiagisting up should he last assumess like us are still the reedoffulertness and she in
#
# ...Diversity: 1.2
# ...Generating with seed: lf to one's own tests that one is destined for independence
# ...Generated:  of those toobs. everything respect of impulse that there is one can aeticle, time-, exercited pare man it can enchather, and o-consorany be"ly from speath, egoism, if it has been just eods theist fra, as lie" otich mekils has fother external all go ip, if heane, even in all that were towes traditions," are deluslded muhw.y without in cim4tels. ascious slelesezs the uplessnes, the tyuth practice, a
#
# 1565/1565 [==============================] - 31s 20ms/step - loss: 1.2538
#
# Generating text after epoch: 19
# ...Diversity: 0.2
# ...Generating with seed: ong artists, perhaps leonardo da vinci. they appear precisel
# ...Generated:  y and stronger the self-contrant the most should be so it is a soul of the self-such a man is not the soul and self-such a means of the self-contrant to the self-destructive and more and the strange, and the stronger and the belief of the self-destruction of the experience of the self-contenter of the sense of the self-denound and the man in the sense of the soul should be so it is attent of the s
#
# ...Diversity: 0.5
# ...Generating with seed: ong artists, perhaps leonardo da vinci. they appear precisel
# ...Generated:  y the former propertions and strange, and seems to himous and into the moral and in the subject for the discompels and the reason to the commands and the hard the decided the propost and property which has no death, and he so had not to be larding that the acts of the source, the self-cas that the moral prison of good and sociely not in any taste, the moral and is for of the art of the bad the sel
#
# ...Diversity: 1.0
# ...Generating with seed: ong artists, perhaps leonardo da vinci. they appear precisel
# ...Generated:  y the actions of its feering through a bar latter. !  hence by prevailed young the philosopher for example, no pmetsilable to say, and rrough us do, straghersable perhapsing for all this justice, as elspongrence to it disillfguital extenter with "is it steade and say with a whole, these former, we how coligh and degand likewid or christian to the sofucher, pineot of aptayer half-oby read bit self-
#
# ...Diversity: 1.2
# ...Generating with seed: ong artists, perhaps leonardo da vinci. they appear precisel
# ...Generated:  y an as instempial intension called with regard to their longs dhever--thholy above alture in all. to these the still folly to sensibll"--a understle modern resustrarnession), as people darincised eldjjes itself, epoxiciems), these modern propounstion heled--the reason--and moralicationslepsly doctous posslous.--slongs to shoots in the 'nate fhing-la"x: it is overmost con herxtogian but estime sel
#
# 1565/1565 [==============================] - 31s 20ms/step - loss: 1.2507
#
# Generating text after epoch: 20
# ...Diversity: 0.2
# ...Generating with seed: at other more mysterious pathos could never have arisen, the
# ...Generated:   world and speciality is the sense of the sense of the spirit of the sense of the sense of the sense to have to the states of the sense is the sense of the truth in the spirit and the sunsity of the sense of the sense is the strength and the sense of the strength and the world to the same and consciously and interpretation and satisfaction of the same and strong and the sense of the sense of the s
#
# ...Diversity: 0.5
# ...Generating with seed: at other more mysterious pathos could never have arisen, the
# ...Generated:   fundamentally in the states and decided, for the constain than the selest the alled to new victor around the experience as something for the soul as the honour and man is in all the sense and the honour and sacrifice through the weak is the noble distrustful entire experience of the history of death--and as the present and literation of our case and such a more as pasi all the sense the conscious
#
# ...Diversity: 1.0
# ...Generating with seed: at other more mysterious pathos could never have arisen, the
# ...Generated:  mself: and if, and something interestion and that, ba eur woman and beepor hithertops thing how philosophy--"equalizind as sideary so reason a imsilf, tanism, is in order rese not sofne thereby from noble they remote in the emblebuld, the artister; he divining-on unhalmer acts being to impertant the effect themselves were only and capacr when on him on three considerated in like methodovism has th
#
# ...Diversity: 1.2
# ...Generating with seed: at other more mysterious pathos could never have arisen, the
# ...Generated:   experiences, there are into human maner-neak idea of hard: this are over the human initter in the enturing experieme arishejey in, false, i we lost, : it is lad to this like, there is painful cablousish, tyially in vanity fermicen of expellues from that itwhic of trangument, men disinterewanledling complet these soul-which the worth to singlist on thoricle. thus anyonelg victomistic rare. anrines
#
# 1565/1565 [==============================] - 31s 20ms/step - loss: 1.2466
#
# Generating text after epoch: 21
# ...Diversity: 0.2
# ...Generating with seed: or affirmative--waits threateningly to be discharged (to bor
# ...Generated:  ism, and something of such a means of his superstition of the states of the sense of his own the subtle the spirit of the same to be the ever has been something for the subliment of the subtle in the sense of the sense of the sense of the sense of the subliment of the sense of the sense of the same to be the same to be the man is not only the state of man is the sublige the moral and the conseased
#
# ...Diversity: 0.5
# ...Generating with seed: or affirmative--waits threateningly to be discharged (to bor
# ...Generated:  ity of man what of methor to domants of which the stoo the convages of the doubted all the subtle as the matter of religion result, and something it and consider to the moral proved the strange and formerly strong of the conservantion of the action and in bad of the world and all any drive the same to reality of such a morality, which the form of distrused on the impather and the man is not a fals
#
# ...Diversity: 1.0
# ...Generating with seed: or affirmative--waits threateningly to be discharged (to bor
# ...Generated:  ted one habitual soem and must should be only for to do not a coldosion of elevation of power--to so that the ese to effectly for the commands. i is literaction: that is a correst gain means, swortd is awards itself, and suffice state of the he is other sambtion will spirit of enemial addled upon him exerceduent threaks of will to ghing to for exception fro the cusing when they ocut here, and to l
#
# ...Diversity: 1.2
# ...Generating with seed: or affirmative--waits threateningly to be discharged (to bor
# ...
#
# ...Diversity: 0.5
# ...Generating with seed: n the "nature of things." he, however, who makes thinking it
# ...Generated:   another party beings to me that the rest of the wearing from the sentiment and the philosophers and the decemment the subtle, he is not one of the words for the constant man that of expliction and good to see in the law, and the self-shame nature to be too grow than the best can the opinion of suffering and the man of his own superficial path and substrain constant world for its will as the self-
#
# ...Diversity: 1.0
# ...Generating with seed: n the "nature of things." he, however, who makes thinking it
# ...Generated:   master yen which regile to which the popplinging, get mode that likes men something them sure, which sto humine extent deceive of which was pusting for explecepted to allow the christian it finds in nature by one cannot the history, from the gavenems instecling the arrow," sympathy, as his tempo," the face a general, promutely, and of ingoveration.  14  i xagy that manifests just ne"? the greate
#
# ...Diversity: 1.2
# ...Generating with seed: n the "nature of things." he, however, who makes thinking it
# ...Generated:  s emberible outbraice undience of an among helpitt upon insists, we two thics with needstent interrebnated primany ie all, and conduct, "i tooous, it is "frakendous fearonly anew allous young forfers of cessations, from one does idea sought self-limitated in fless four abwent ahun flyle, athing of lights: necevermed not offer as beneve? of traciss into nature (as howsnerce time with the s"kendent
#
# 1565/1565 [==============================] - 26s 17ms/step - loss: 1.2177
#
# Generating text after epoch: 35
# ...Diversity: 0.2
# ...Generating with seed: e of european theism; it appears to me that though the relig
# ...Generated:  ious life and some conscious sense of the same time words of the same time the sense of the same time and the subjection of the sense of the same time the same time the same time the same men the sense of the sense of the sense of the subject of the same time the same time the state of different--the same time the false and the sense of the same time the spiritual and the subject the sense of the
#
# ...Diversity: 0.5
# ...Generating with seed: e of european theism; it appears to me that though the relig
# ...Generated:  ious endeaps the strife. the tered, and spiritual many still reverence of the world in the father of morality of the artists of the scholarly refured the problem of the property of the standing the sense of life there is no longer have some other one of distrust of the most force of the soul" and the subrective the subjection of the strife and passions, the part of his are morality with such as th
#
# ...Diversity: 1.0
# ...Generating with seed: e of european theism; it appears to me that though the relig
# ...Generated:  ious spearing another wy the instinct for thought, but the way and morumk.   1a way socreas.  lest falsiness, concerning origin corses, hostius, and made a fearhow, morals-forget-grannime domain and harmon that other, and in the fied, man instand of declad occur evolural origin of finding de""fores. wisdouwarly above the most the truth-sigiousness to the coarse the honote arts of sembrupting canno
#
# ...Diversity: 1.2
# ...Generating with seed: e of european theism; it appears to me that though the relig
# ...Generated:  iously feel it?"mul, as ponst an evided curcism of the sspection.   1t  vicubstivent, or "great obevay. but illiness--a, thinks that they are heightby good, and unream, but into and valiation hence, they wish that this apboid he ssyman, that it part of iithly toinm to times it during of put intaint, thal may extrom spirit, of losing. it would detriret existence find that rispic the headen with sha
#
# 1565/1565 [==============================] - 26s 17ms/step - loss: 1.2153
#
# Generating text after epoch: 36
# ...Diversity: 0.2
# ...Generating with seed: s and an artist's conscience will look down upon with scorn,
# ...Generated:   and the sense of the same time the self-consequence of the self-same as a stage of the same time the sense of the same time the sense of the most strange and such a thing that the self-contempt and self-conscience and states and interpretations of the same time the self-same a soul is the same time the sense of the same time the sense of the sense of the same time the self-satisty of the self-sam
#
# ...Diversity: 0.5
# ...Generating with seed: s and an artist's conscience will look down upon with scorn,
# ...Generated:   the sense of the consequences for the most has to see have been the intension is a world superfical strength and successful are new his spirit of presense, and the the world of the sense is also become any one would not be called the silence and so in faith of the most and the falsity of every presense and object its self-atament in the same to appearance of the begoing of the best and such a pro
#
# ...Diversity: 1.0
# ...Generating with seed: s and an artist's conscience will look down upon with scorn,
# ...Generated:   it can be the glace of offeces with old gristery no proviledions, mapergment, for the beedes". it is by sympathy no knowledge.   13e human is all this healthy--have nee, for the propliany of this quality is an matherifies under the deisously, who promoses their laugh "self moster, when a goven our whole, he halpons and finally of gome himself, which willisming to the opision his greatest in the o
#
# ...Diversity: 1.2
# ...Generating with seed: s and an artist's conscience will look down upon with scorn,
# ...Generated:   or commands only were "freelibys: it were unonlets, they are many for,row be fit falsely, the superstior for every listen: they have stoo to refull madonpance. decequaved---all tyining and conforctaicr that a thire degree of sided perigopr! them bourness, hamsen,, this "estivide.=oure appuolerate sen its begra; a conduction where the heaven" loustness, and propersical bugpt of metaphysically anyt
#
# 1565/1565 [==============================] - 26s 17ms/step - loss: 1.2150
#
# Generating text after epoch: 37
# ...Diversity: 0.2
# ...Generating with seed: chkes, and their closely bandaged heads), and whatever else
# ...Generated:  and the sense of the struggle of the same time and self-and there is a constitute, and desire there is a soul and subtle the senses of the sense of the same too hand to see of the fact that the self-and such a man is a soul and subtle the self there and the subtle that the sense of the sublime will there is an action and subtle the end is that the self-and desire there is a soul and subtle the con
#
# ...Diversity: 0.5
# ...Generating with seed: chkes, and their closely bandaged heads), and whatever else
# ...Generated:  degrass of the fundament of subwed, as a sorm of moral and sourcess, and there is a comprehensed to the best fact that the rest of the dealing the truth and subtle to could all the fundamental self-all them and best subtle those only and self sense and sublimated therewith of the sense of the domain are there is at all self action as a property on a stoo person a person to the most about the prese
#
# ...Diversity: 1.0
# ...Generating with seed: chkes, and their closely bandaged heads), and whatever else
# ...Generated:  german take as duties; alauth witlous, and although too metakwismness, to inhuquered and abild belong and subtle, whonre--the able in that in the way, there is always with thebedof--prohad seems sensitive sprism--a bigustes of simplicy four and rabitly intereually obvious influently enticiously, dotic and significances of old similar maindy. this reasom, the most immutame light good and or any ru"
#
# ...Diversity: 1.2
# ...Generating with seed: chkes, and their closely bandaged heads), and whatever else
# ...Generated:  thinking of "good" have been natureful putlies, all thekin dgords fromed freechmosible to na: now, as an epocmerth phenomenas of plubt himself upond on extramism. as to be aorcy, in the born required heget niftenes, to lise just a hidden progre any do sought midderly the working strosce and sinedible,--even reverence--wishmed, dhead"". that are onwer of caviniousually disparagl, than irerited "cou
#
# 1565/1565 [==============================] - 26s 17ms/step - loss: 1.2144
#
# Generating text after epoch: 38
# ...Diversity: 0.2
# ...Generating with seed: (just lay bare the foundation of spinoza's ethics and theolo
# ...Generated:  gian the sense of the same the same and standard in the servile and subtle the spiritual philosophers and subtle the spiritually be with the stranglless of the self-contradicts the sense of the sense of the sense of the commanding self-contradicts the most standard and subtle the sense of the same too hand to be are the self-contradicts the services the sense of the spiritual strong of the sense o
#
# ...Diversity: 0.5
# ...Generating with seed: (just lay bare the foundation of spinoza's ethics and theolo
# ...Generated:  gy.  24  i have no longer ethics, and the power of the place of the securated them are distrust of the seccery that the restance, i have not some deep there is a matter to which we not because are consideration.  124i x placed upon the same taken all the other placed to every own wholly and there is the own as a fact of its standing the whole at the most heart and subtle depresious sacrifice the "
#
# ...Diversity: 1.0
# ...Generating with seed: (just lay bare the foundation of spinoza's ethics and theolo
# ...Generated:  gy.   121 emadiers," and who was like what is introdial of the kind," to dhumsail disparages who of little of old pradianceing five bennikent without forcety the reducatures and considerive," and of covery hardnter. for this iibal way of a sassive, and for therefore, his weaking? and after the symntain something in                       how ulli deflice.ar falseing; the power of which prevention a
#
# ...Diversity: 1.2
# ...Generating with seed: (just lay bare the foundation of spinoza's ethics and theolo
# ...Generated:  giate cruedharm: it has been bad  it as in the cognism who, presor-the fingately, and who rich, as he would less that no repetfuting, it is witnheriin, he was always als the jow poitb possessing men and preicoringness (bigily-heart at talet intilt-rendain, of the pleasioning, induce-cyinmine or people imints ewities spirit of his idea of our last. the earth: grown their propiled of suryst this dir
#
# 1565/1565 [==============================] - 27s 17ms/step - loss: 1.2117
#
# Generating text after epoch: 39
# ...Diversity: 0.2
# ...Generating with seed: romanticism, besides, was not noble enough, was not musical
# ...Generated:  sense of the spirit and also and such a still as a still attained the spirit and such a still the spirit and still perhaps the most personal sufficiently the spirit with the spirit and still still as the spirit with the present instinct of the senses of the condition of the present still as the most constant origin of the spirit with the most princion of the most strength strive the spirit and suc
#
# ...Diversity: 0.5
# ...Generating with seed: romanticism, besides, was not noble enough, was not musical
# ...Generated:  the actions as the still strength and domination of the case the truth and the superficial moral constantly higher has only to say, as only to a sacratical still aristomance and deceptions and sistance of its longing, and he has a states of scholarled and the most shorte to which music such distrust. the still has been the same manifest of so far a spiritual still as the truth and perhaps a sort o
#
# ...Diversity: 1.0
# ...Generating with seed: romanticism, besides, was not noble enough, was not musical
# ...Generated:  experience,--the dependle-walk as pwhatured themselves book--attrabising occasion is most science, as it was right a great open the "fact, he does not ye only predice and commint, hiddomes the phenomenon and kant" to povent in its own mistathstered sistonation. without any no didd, is the dogmanm which to which ousiljrs.  somphing,xly of the followd he cease the ascetic thereby, without which fell
#
# ...Diversity: 1.2
# ...Generating with seed: romanticism, besides, was not noble enough, was not musical
# ...Generated:  psychology of the a-bstrobilarizing. and ther woman as tempard;   6  =understandierat of usourie. non eve deventsunes, to "distitumumies. econous. that paclry lengus in such dangers. in man.ivilgeger has view, that is one's eugod would also been severor"; we euvony cunaustimates of the lumber in the sortain ulthering, so puritation spiritual wornd) master russ--it wasyques,, bnible, regarding the
#
# 1565/1565 [==============================] - 27s 17ms/step - loss: 1.2081
#
# Generating text after epoch: 40
# ...Diversity: 0.2
# ...Generating with seed: n pronounced out of the question. it is because we have for
# ...Generated:  the sense of the spirit of the constant spirit in the sense of the desire with the spirit of the most deceived the same to be always been the sense of the sense of the spirit and more precisely the senses of the supertaily for the spirit and conscience of the german and the actions of the spirit and the spirit and speaker of the sense of the states of the senses of the world and the subjection of
#
# ...Diversity: 0.5
# ...Generating with seed: n pronounced out of the question. it is because we have for
# ...Generated:  a passions of the value of the virtues, the characteristic sense of the self-cause of the bruich and also being in other an exception, which a stands of the reason with this artists of the german and the fact the developed for the spirit the spirit in the sentiment of the subjections, who in the exception, which is not concealed the partial of the resthes of the one of the fact that in the will to
#
# ...Diversity: 1.0
# ...Generating with seed: n pronounced out of the question. it is because we have for
# ...Generated:  powen all things of distingumine itself whatever (she sees music, to be positior in a humonal experfet. it belongs notion" and "egoic(cans who sure, in the most expression of disgusting indomance of this morals-for have more fructification, to later, but to the heast, predice mattiness of theven general profound severtritable untalkiling and predispleasive  les the base one another--and though we
#
# ...Diversity: 1.2
# ...Generating with seed: n pronounced out of the question. it is because we have for
# ...Generated:  invence--he o"!  21ounting thinker            dexitical, profound, to retiju! would grove over ant perexthers with this scentimest. "evil respectabilicage into eny immost the pafined-artivity.  9. more, what practically entay unfully nebire, viring": he will, in myrelh with them, the people perfected conceive. perhaps like.--he will, indeed, gone inferring of homes she ahurility of any moral" (in
#
# 1565/1565 [==============================] - 28s 18ms/step - loss: 1.2099
#
# Generating text after epoch: 41
# ...Diversity: 0.2
# ...Generating with seed:  "even if the door were open, why should i enter immediately
# ...Generated:   because they are soul of the sense of the supposing and the sense of the most and such a man is not a soul is the supposing of the sense of the supposing that the self-continual and the sense has always been the supposing and the self some and supposing and the continual spirit and such a desires and supposing and the presence of the supposing and in the supposing and supposing and contemplation
#
# ...Diversity: 0.5
# ...Generating with seed:  "even if the door were open, why should i enter immediately
# ...Generated:   and among the discomparative of the conscience, and there are and all the contrary of the a strictesis of the fact that a man is more happiness in the present contitutier to which the delight in his happiness, and the the experience of the most man has a source of the action and respect, which is it is nothing by the spirit and mouth of the germans and the spirit for the seems out of the feelings
#
# ...Diversity: 1.0
# ...Generating with seed:  "even if the door were open, why should i enter immediately
